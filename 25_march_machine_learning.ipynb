# %%
Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the
dataset have?

# %%
#importing basics libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_excel('flight_price.xlsx')

# %%
df.shape
# Out:
# (10683, 11)

# %%
Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the
distribution.

# %%
the distribution of flight prices in the dataset is right skwed

# %%
sns.histplot(df['Price'],bins=50,kde=True)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %%
Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
df['Price'].describe()
#the range of prices in the dataset 1759 which is minimum and maximum is 79512.0
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %% [markdown]
# Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x=df['Airline'],y=df['Price'])
# Out:
# <AxesSubplot: xlabel='Airline', ylabel='Price'>

# %% [markdown]
# Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
# they may impact your analysis.

# %%
As we observed we have outliers in dataset
The outlier may impact the analysis of taking wrong decision on dataset

# %%
df.boxplot()
# Out:
# <AxesSubplot: >

# %%
Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
to identify the peak travel season. What features would you analyze to identify the peak season, and how
would you present your findings to your boss?

# %%
df['Date']=df['Date_of_Journey'].str.split('/').str[0]
df['Month']=df['Date_of_Journey'].str.split('/').str[1]
df['Year']=df['Date_of_Journey'].str.split('/').str[2]

# %%
df['Date']=df['Date'].astype(int)
df['Month']=df['Month'].astype(int)
df['Year']=df['Year'].astype(int)

# %%
df['Month'].unique()
# Out:
# array([3, 5, 6, 4])

# %%
plt.figure(figsize=(15,10))
sns.histplot(df['Month'])
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Count'>

# %%
by seeing qabove we use month category for the calculate peak seqason and in which 5th and 6th month is highest peak season

# %%
df['Price'].unique()
# Out:
# array([ 3897,  7662, 13882, ...,  9790, 12352, 12648])

# %%
Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
Price dataset to identify any trends in flight prices. What features would you analyze to identify these
trends, and what visualizations would you use to present your findings to your team?

# %%
As a data analyst analyzing the Flight Price dataset, there are several features you can consider to identify trends in flight prices. Here are some key features you should analyze:

Date/Time: Analyzing flight prices over time can help identify seasonal trends, such as price fluctuations during holidays or peak travel seasons.

Departure and Arrival Locations: Comparing flight prices across different departure and arrival locations can reveal price variations based on distance, popularity, or demand for specific routes.

Airline: Analyzing flight prices by different airlines can provide insights into variations in pricing strategies or competitiveness among carriers.

Duration: Examining flight prices based on the duration of the flight can help identify if there is a relationship between flight duration and price.

Booking Class: Analyzing flight prices by different booking classes (economy, business, first class) can highlight price differences based on the level of service and amenities offered.

To present your findings to your team, you can use various visualizations. Here are a few examples:

Line Chart: Use a line chart to display the trend in flight prices over time. The x-axis represents the time period (e.g., months or years), and the y-axis represents the average flight price. You can plot multiple lines for different departure and arrival locations or airlines to compare trends.

Bar Chart: Utilize a bar chart to compare average flight prices across different departure and arrival locations or airlines. The x-axis represents the categories (locations or airlines), and the y-axis represents the average flight price. This visualization can help identify price differences and rankings.

Box Plot: A box plot can provide a summary of flight prices, showing the minimum, first quartile, median, third quartile, and maximum values. This visualization is useful for understanding the distribution of flight prices across different categories like departure and arrival locations or airlines.

Heatmap: Create a heatmap to visualize flight prices by combining departure and arrival locations. The heatmap can display color-coded values, where the intensity of the color represents the average flight price. This visualization can help identify patterns in flight prices based on specific routes.

Scatter Plot: Use a scatter plot to analyze the relationship between flight duration and price. The x-axis represents the flight duration, and the y-axis represents the flight price. Each data point represents a flight, and you can use different colors or shapes to differentiate airlines or departure and arrival locations.

# %%
Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
identify these factors, and how would you present your findings to the management team?

# %%
As a data scientist analyzing the Flight Price dataset to identify the factors that affect flight prices, there are several features you can consider. Here are some key features to analyze:

1. Departure and Arrival Locations: Analyzing flight prices based on different departure and arrival locations can help identify the impact of routes and geographical factors on prices.

2. Airline: Examining flight prices by different airlines can reveal pricing strategies, brand value, and market competition, which can influence prices.

3. Date/Time: Analyzing flight prices over time can identify seasonal trends, such as price fluctuations during holidays or peak travel seasons. It can also reveal the impact of demand and supply dynamics on prices.

4. Duration: Examining flight prices based on the duration of the flight can help identify the relationship between flight duration and prices. Longer flights might be more expensive due to factors like fuel costs and additional services.

5. Booking Class: Analyzing flight prices by different booking classes (economy, business, first class) can help understand how fare class affects prices, considering the level of service and amenities provided.

6. Advance Booking: Investigating flight prices based on the lead time between booking and departure can highlight if there is a correlation between early booking and lower prices.

7. Competition: Assessing the number of competing airlines on a specific route or at a particular departure location can provide insights into price competitiveness and its impact on flight prices.

To present your findings to the management team, consider the following approaches:

1. Executive Summary: Begin with a concise summary of your findings, highlighting the key factors that significantly affect flight prices.

2. Visualizations: Use relevant visualizations to present your findings effectively. Bar charts, line charts, scatter plots, and heatmaps can be utilized to showcase patterns and relationships between flight prices and the analyzed features.

3. Statistical Analysis: Conduct statistical analyses, such as regression analysis, to quantify the impact of different factors on flight prices. Present the coefficients, significance levels, and other relevant statistical measures to support your conclusions.

4. Data-driven Insights: Provide clear and actionable insights based on your analysis. Explain the impact of each factor on flight prices and suggest strategies or recommendations to optimize pricing based on the findings.

5. Presentation Slides or Reports: Create visually appealing presentation slides or reports that summarize your findings and recommendations concisely. Use charts, tables, and bullet points to communicate key insights effectively.

6. Q&A Session: Prepare for a question-and-answer session to address any queries or concerns the management team may have. Be prepared to explain your analysis methodologies, assumptions, and limitations.

# %%
Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
the dataset have?

# %%
df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# %%
df.shape
# Out:
# (10841, 13)

# %%
Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
app categories.

# %%
plt.figure(figsize=(20,20))
sns.boxplot(x=df['Category'],y=df['Rating'])
# Out:
# <AxesSubplot: xlabel='Category', ylabel='Rating'>

# %%
Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
impact your analysis.

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
As we see there are missing values in dataset,Rating,Type,Content Rating,current version,Android version
when we dont handle the missing values we get a wrong output during training and testing of model

# %%
Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
the relationship.

# %%
df['Size']=df['Size'].str.replace('M','000')
df['Size']=df['Size'].str.replace('k','')
df['Size']=df['Size'].replace('Varies with device',np.nan)

# %%
df['Size'].dropna(inplace=True)

# %%
df['Size'].unique()

# %%
df['Size']=df['Size'].str.replace(',','')

# %%
df['Size']=df['Size'].astype(float)

# %%
sns.scatterplot(x=df['Rating'],y=df['Size'])
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Size'>

# %%
As we see above scatterplot the rating and size of application is not symetrical proportional,size of an app an increases but applicaction rating is constant

# %%
Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
df.groupby(['Category']).mean()
# Out:
# /tmp/ipykernel_84/1625824254.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Category']).mean()
#                         Rating          Size
# Category
# 1.9                  19.000000   1000.000000
# ART_AND_DESIGN        4.358065   9470.645161
# AUTO_AND_VEHICLES     4.190411  17923.262667
# BEAUTY                4.278571  10939.029787
# BOOKS_AND_REFERENCE   4.346067  10354.897970
# BUSINESS              4.121452  11962.175000
# COMICS                4.155172  11199.405882
# COMMUNICATION         4.158537   9725.352830
# DATING                3.970769  14181.776415
# EDUCATION             4.389032  19299.528829
# ENTERTAINMENT         4.126174  20823.253333
# EVENTS                4.435556  11587.185965
# FAMILY                4.192272  26698.002238
# ...

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews     Size  Installs  Type Price Content Rating  \
# 0     159  19000.0   10,000+  Free     0       Everyone
# 1     967  14000.0  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder=OneHotEncoder()

# %%
encode=encoder.fit_transform(df[['Category']])

# %%
plt.figure(figsize=(15,20))
sns.barplot(x=df['Category'],y=df['Price'])
# Out:
# <AxesSubplot: xlabel='Category', ylabel='Price'>

# %%
Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
with the highest number of installs.

# %%
df_cat_installs = df.groupby(['Category'])['Installs'].sum().sort_values(ascending = False).reset_index()
df_cat_installs.Installs = df_cat_installs.Installs/1000000000# converting into billions
df2 = df_cat_installs.head(10)
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df2 )
ax.set_xlabel('No. of Installations in Billions')
ax.set_ylabel('')
ax.set_title("Most Popular Categories in Play Store", size = 20)
# Out:
# Text(0.5, 1.0, 'Most Popular Categories in Play Store')

# %%
Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
Google Playstore dataset to identify the most popular app categories. How would you approach this
task, and what features would you analyze to make recommendations to the company?

# %%
a. Count of Apps: Calculate the count of apps in each category to determine the popularity based on the number of apps available.

b. Downloads: If available, analyze the number of downloads for each app category. This can provide insights into the popularity of categories based on user demand.

c. Ratings: Analyze average ratings or user reviews for apps in each category. Higher ratings may indicate greater user satisfaction and popularity.

d. Revenue: If the dataset includes revenue or monetization metrics, such as in-app purchases or ad revenue, you can analyze these to gauge the financial success and popularity of different app categories.

e. Growth Trends: Consider analyzing the growth trends of app categories over time. This can provide insights into emerging popular categories or those experiencing declining popularity.

Visualize the Findings: Use visualizations such as bar charts, pie charts, or stacked bar charts to present the distribution and popularity of app categories. Visualizations can help stakeholders quickly grasp the information and make informed decisions.

Recommendations: Based on the analysis, provide recommendations to the company regarding the most popular app categories. Consider the market trends, competition, and the company's goals and capabilities. Suggest categories that align with the company's strengths and have a good balance of popularity, user demand, and growth potential.

# %%
Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the
most successful app developers. What features would you analyze to make recommendations to the
company, and what data visualizations would you use to present your findings?

# %%
Number of Downloads: Analyze the total number of downloads for apps developed by different companies. This can provide an indication of popularity and user demand. You can calculate the cumulative downloads for each developer.

Data Visualization: Use a bar chart or a stacked bar chart to compare the number of downloads for different developers. The x-axis represents the developers, and the y-axis represents the total number of downloads.
Average User Ratings: Analyze the average ratings of apps developed by different companies. Higher average ratings indicate user satisfaction and quality of apps.

Data Visualization: Use a bar chart or a box plot to compare the average ratings for different developers. The x-axis represents the developers, and the y-axis represents the average ratings.
Number of Apps and Portfolio Size: Analyze the number of apps developed by each company and the size of their app portfolio. A larger number of apps may indicate experience and a successful track record.

Data Visualization: Use a bar chart or a pie chart to compare the number of apps developed by different companies. The x-axis or the different slices of the pie chart represent the developers, and the y-axis or the size of the slices represents the number of apps.
Revenue Generation: If available, analyze revenue-related metrics such as in-app purchases, ad revenue, or subscription revenue generated by apps developed by different companies. This can help identify financially successful developers.

Data Visualization: Use a bar chart or a stacked bar chart to compare the revenue generated by different developers. The x-axis represents the developers, and the y-axis represents the revenue.

# %%
Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to
launch a new app. What features would you analyze to make recommendations to the company, and
what data visualizations would you use to present your findings?

# %%
Monthly Downloads: Analyze the monthly downloads of existing apps in the Google Playstore dataset to identify trends and patterns throughout the year. This can help identify months or seasons with higher user activity and demand.

Data Visualization: Use a line chart or a bar chart to plot the monthly downloads over time. The x-axis represents the months or time periods, and the y-axis represents the number of downloads. This visualization will help identify the months with peak or low download activity.
User Ratings: Analyze the average user ratings of apps by month to understand the user satisfaction levels throughout the year. This can provide insights into the months with higher user engagement and positive feedback.

Data Visualization: Use a line chart or a bar chart to plot the average user ratings over time. The x-axis represents the months or time periods, and the y-axis represents the average ratings. This visualization will help identify the months with higher user satisfaction.
Seasonal Trends: Analyze the dataset for any seasonal trends or patterns that might affect app launches. For example, consider holidays, festivals, or vacation seasons that could impact user behavior and app usage.

Data Visualization: Use a heatmap or a calendar chart to visualize the occurrence and intensity of user activity or downloads across different months. This visualization will help identify specific months or periods associated with increased user engagement.
Competition Analysis: Analyze the number of new app launches and competition during different months. Identify months with lower competition or high success rates for new app launches.

Data Visualization: Use a stacked bar chart to compare the number of new app launches by month. The x-axis represents the months, and the y-axis represents the count of app launches. This visualization will help identify months with lower competition.
Market Analysis: Conduct market research outside of the Google Playstore dataset to identify trends in the overall mobile app industry. Consider reports, industry analysis, or studies that highlight trends and user behavior patterns relevant to app launches.
